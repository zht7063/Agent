# %% [markdown]
# # 人工干预 Human in the loop
#
# 人工干预（Human-in-the-loop）中间件允许我们为代理工具调用添加人工监督。当模型提出一个可能需要审核的操作时——例如写入文件或执行 SQL——中间件可以暂停执行并等待人工决策。
#
# 该中间件通过将每个工具调用与可配置的策略进行比对来实现这一点。如果需要人工干预，中间件会发出一个中断信号，暂停执行。执行状态将通过 LangGraph 的持久化层保存，因此可以安全地暂停并稍后恢复执行。
#
# 然后由人工决策决定下一步操作：该操作可以原样批准（approve）、在运行前进行修改（edit），或被拒绝并提供反馈（reject）。

# %%
# 配置开发环境
import os
from dotenv import load_dotenv
from pathlib import Path


load_dotenv()
root_path = Path.cwd().parent.parent

str(root_path), os.getenv("OPENAI_BASE_URL"), os.getenv("OPENAI_API_KEY")
# Out:
# ('/home/zht/projects/Agent',
#  'https://api.openai-proxy.org/v1',
#  'sk-A7irm5LFwUUuMHPQ58V5qnygQQEYOGm4J8bfiUo5jm8N0lai')

# %% [markdown]
# 我们首先创建两个 tool 用于后续演示：

# %%
from langchain.tools import tool

@tool
def get_user_info(user_id: str) -> str:
    """ 获取用户信息 """
    return f"用户 {user_id} 的信息"


@tool 
def write_file(file_path: str, content: str) -> str:
    """ 写入文件 """
    return f"文件 {file_path} 已写入, 内容为 {content}"

# %% [markdown]
# 显然此时写入文件的风险比较大一些，所以我们在创建 agent 的时候，要为该工具的执行添加人工干预。
#
# 下面先创建一个代理：

# %%
from langchain.chat_models import init_chat_model
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage


agent = create_agent(
    model = init_chat_model("openai:gpt-4o-mini"),
    tools = [get_user_info, write_file],
)

resp = agent.invoke(
    input = {
        "messages": [
            HumanMessage(content="请根据用户 id 获取用户信息：iris_10001"),
            HumanMessage(content="请根据用户信息写入文件: user_id: iris_10001 content: age: 20"),
        ]
    }
)

resp
# Out:
# {'messages': [HumanMessage(content='请根据用户 id 获取用户信息：iris_10001', additional_kwargs={}, response_metadata={}, id='26c0f916-ec50-413d-a6ac-d7b34b86e9f4'),
#   HumanMessage(content='请根据用户信息写入文件: user_id: iris_10001 content: age: 20', additional_kwargs={}, response_metadata={}, id='4cb3ab8e-dccd-4fae-a978-f76b628bb2c7'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 103, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch5kww2vIukC8OisSaG4ycnMB7eqb', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--d07e6efb-b876-4705-b7aa-dedc297d5f24-0', tool_calls=[{'name': 'get_user_info', 'args': {'user_id': 'iris_10001'}, 'id': 'call_XjFB6LVgERQCbAg351XbOMP7', 'type': 'tool_call'}, {'name': 'write_file', 'args': {'file_path': 'user_info.txt', 'content': 'user_id: iris_10001\ncontent: age: 20'}, 'id': 'call_vxv21DbcWRHYWKeTQ8Ha7xvj', 'type': 'tool_call'}], usage_metadata={'input_tokens': 103, 'output_tokens': 70, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='用户 iris_10001 的信息', name='get_user_info', id='e0164878-5e0f-47fd-b63b-1db13b317b03', tool_call_id='call_XjFB6LVgERQCbAg351XbOMP7'),
#   ToolMessage(content='文件 user_info.txt 已写入, 内容为 user_id: iris_10001\ncontent: age: 20', name='write_file', id='cd68a281-1777-4c31-92b7-18fa9712a05d', tool_call_id='call_vxv21DbcWRHYWKeTQ8Ha7xvj'),
#   AIMessage(content='1. 用户 iris_10001 的信息已成功获取。\n2. 文件 `user_info.txt` 已写入，内容为：\n\n```\nuser_id: iris_10001\ncontent: age: 20\n```', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 257, 'total_tokens': 305, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch5kxS1S2S854xy1csMHQJvbcfhpA', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--da2dc03b-59d4-4c68-b375-59e8e9b91af4-0', usage_metadata={'input_tokens': 257, 'output_tokens': 48, 'total_tokens': 305, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# 在没有人工干预的情况下，代理通常会自动调用工具，所以我们需要通过 HITL 中间件为其设置中断：

# %%
from langchain.agents.middleware import HumanInTheLoopMiddleware 
from langgraph.checkpoint.memory import InMemorySaver 


# 定义 HITL 中间件
human_in_the_loop = HumanInTheLoopMiddleware(
    interrupt_on = {
        "write_file": True,
        "get_user_info": False,
    },
    description_prefix="Tool execution pending approval",
)

agent = create_agent(
    model = init_chat_model("openai:gpt-4o-mini"),
    tools = [get_user_info, write_file],
    middleware=[human_in_the_loop],
    checkpointer=InMemorySaver(),
)

# %% [markdown]
# 接下来我们演示一下，加入 HITL 之后，工具调用会产生什么变化：

# %% [markdown]
# 首先尝试调用获取信息的工具：

# %%
config = {"configurable": {"thread_id": "t_10086"}} 

resp = agent.invoke(
    input = {
        "messages": [
            HumanMessage(content="请根据用户 id 获取用户信息：iris_10001"),
        ]
    },
    config = config
)

resp
# Out:
# {'messages': [HumanMessage(content='请根据用户 id 获取用户信息：iris_10001', additional_kwargs={}, response_metadata={}, id='7e251726-4923-4b92-ac45-15ed1f7855a8'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 78, 'total_tokens': 98, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch66LlhV5Mi8RhplQrQRcpC1ysgm7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--4ce36ab4-7924-472d-9c78-bc01719b56f8-0', tool_calls=[{'name': 'get_user_info', 'args': {'user_id': 'iris_10001'}, 'id': 'call_oS6LsoGgkSeVwnKokBPgeunV', 'type': 'tool_call'}], usage_metadata={'input_tokens': 78, 'output_tokens': 20, 'total_tokens': 98, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='用户 iris_10001 的信息', name='get_user_info', id='f1d24697-3d93-4bcd-897d-213bce58596c', tool_call_id='call_oS6LsoGgkSeVwnKokBPgeunV'),
#   AIMessage(content='用户 iris_10001 的信息已获取。请问您需要什么具体的信息？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 113, 'total_tokens': 133, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch66MhrlIUV6uvkTLA2N8LUl7ua5x', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ce6a069a-1700-4265-8701-e94fe6730655-0', usage_metadata={'input_tokens': 113, 'output_tokens': 20, 'total_tokens': 133, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# 然后尝试调用需要人工审核的工具：

# %%
resp = agent.invoke(
    input = {
        "messages": [
            HumanMessage(content="写入用户信息：user_id: iris_10001 content: age: 20"),
        ]
    },
    config = config
)

resp
# Out:
# {'messages': [HumanMessage(content='请根据用户 id 获取用户信息：iris_10001', additional_kwargs={}, response_metadata={}, id='7e251726-4923-4b92-ac45-15ed1f7855a8'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 78, 'total_tokens': 98, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch66LlhV5Mi8RhplQrQRcpC1ysgm7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--4ce36ab4-7924-472d-9c78-bc01719b56f8-0', tool_calls=[{'name': 'get_user_info', 'args': {'user_id': 'iris_10001'}, 'id': 'call_oS6LsoGgkSeVwnKokBPgeunV', 'type': 'tool_call'}], usage_metadata={'input_tokens': 78, 'output_tokens': 20, 'total_tokens': 98, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='用户 iris_10001 的信息', name='get_user_info', id='f1d24697-3d93-4bcd-897d-213bce58596c', tool_call_id='call_oS6LsoGgkSeVwnKokBPgeunV'),
#   AIMessage(content='用户 iris_10001 的信息已获取。请问您需要什么具体的信息？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 113, 'total_tokens': 133, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch66MhrlIUV6uvkTLA2N8LUl7ua5x', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ce6a069a-1700-4265-8701-e94fe6730655-0', usage_metadata={'input_tokens': 113, 'output_tokens': 20, 'total_tokens': 133, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='写入用户信息：user_id: iris_10001 content: age: 20', additional_kwargs={}, response_metadata={}, id='3b0b0068-1403-48da-b1f8-90f236fa03f4'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 157, 'total_tokens': 193, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch66OLMif4pT4bL6OqN46v9elVznv', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--3f780e96-754e-4d78-ae21-570b86bbffdb-0', tool_calls=[{'name': 'write_file', 'args': {'file_path': 'iris_10001_info.txt', 'content': 'user_id: iris_10001\nage: 20'}, 'id': 'call_WrgEVUhZO7CCGZC7K1qGc85Y', 'type': 'tool_call'}], usage_metadata={'input_tokens': 157, 'output_tokens': 36, 'total_tokens': 193, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'write_file', 'args': {'file_path': 'iris_10001_info.txt', 'content': 'user_id: iris_10001\nage: 20'}, 'description': "Tool execution pending approval\n\nTool: write_file\nArgs: {'file_path': 'iris_10001_info.txt', 'content': 'user_id: iris_10001\\nage: 20'}"}], 'review_configs': [{'action_name': 'write_file', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='3564c5f375cbbc89f5cb30fb45605d2c')]}

# %% [markdown]
# 显然，这次 resp 的最后一条内容不是 AIMessage，而是变成了 `__interrupt__` 字段，其中列出了需要审核的操作。
#
# 我们可以将这些操作显示出来，并让人工审核对其进行决策。

# %%
from langgraph.types import Command

# 获取所有中断
if resp.get("__interrupt__"):
    hitl_req = resp["__interrupt__"][0].value

    action_requests = hitl_req["action_requests"]
    review_configs = hitl_req["review_configs"]  # 里面写着允许的决策类型

    # 简单打印一下要人工确认的操作
    for action in action_requests:
        print("需要人工确认的工具:", action["name"])
        print("参数:", action["args"])
else:
    print("没有触发中断，直接看 resp['messages'] 即可")
# Out:
# 需要人工确认的工具: write_file
# 参数: {'file_path': 'iris_10001_info.txt', 'content': 'user_id: iris_10001\nage: 20'}

# %% [markdown]
# 接下来我们在新的线程中调用模型并处理中断：

# %%
from langgraph.types import Command


config = {"configurable": {"thread_id": "114514"}}

resp = agent.invoke(
    input = {
        "messages": [
            HumanMessage(content="写入用户信息：user_id: iris_10001 content: age: 20"),
        ]
    },
    config = config
)


resp
# Out:
# {'messages': [HumanMessage(content='写入用户信息：user_id: iris_10001 content: age: 20', additional_kwargs={}, response_metadata={}, id='11b05285-65ac-4f73-a221-c68198873176'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 84, 'total_tokens': 122, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6NXLrULV2Y9zOw1zWNxvdWNEXd1', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6b9a9873-b1ae-4cce-bc8b-9462b2265bc1-0', tool_calls=[{'name': 'write_file', 'args': {'file_path': 'user_info_iris_10001.txt', 'content': 'user_id: iris_10001\nage: 20'}, 'id': 'call_c0FYL4BzdDPYpCVDOBWh1ZuJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 84, 'output_tokens': 38, 'total_tokens': 122, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='文件 user_info_iris_10001.txt 已写入, 内容为 user_id: iris_10001\nage: 20', name='write_file', id='5cf5166b-19e5-4731-8b7f-16155038c2f1', tool_call_id='call_c0FYL4BzdDPYpCVDOBWh1ZuJ'),
#   AIMessage(content='用户信息已成功写入，文件名为 `user_info_iris_10001.txt`，内容如下：\n\n```\nuser_id: iris_10001\nage: 20\n```', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 156, 'total_tokens': 198, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6NYEd2wKgLcG2Ij4jXB0GENKCT6', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--243a5def-cecc-4f25-8e54-025a1e8f0549-0', usage_metadata={'input_tokens': 156, 'output_tokens': 42, 'total_tokens': 198, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='写入用户信息：user_id: iris_10001 content: age: 20', additional_kwargs={}, response_metadata={}, id='29a94b59-b973-4c3e-9a4f-41264997e6fd'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 222, 'total_tokens': 260, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6Pvu6FgpPRlRn9DFiMeAn1NXzx5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--eb8a578f-c3fe-40af-9b97-012794a66617-0', tool_calls=[{'name': 'write_file', 'args': {'file_path': 'user_info_iris_10001.txt', 'content': 'user_id: iris_10001'}, 'id': 'call_BHbEklckoRNTfwnV56wdQdrk', 'type': 'tool_call'}], usage_metadata={'input_tokens': 222, 'output_tokens': 38, 'total_tokens': 260, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='文件 user_info_iris_10001.txt 已写入, 内容为 user_id: iris_10001', name='write_file', id='af286ee0-743f-42c7-af3e-c218e93c25dc', tool_call_id='call_BHbEklckoRNTfwnV56wdQdrk'),
#   AIMessage(content='用户信息已成功写入，文件名为 `user_info_iris_10001.txt`，内容如下：\n\n```\nuser_id: iris_10001\n```', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 284, 'total_tokens': 321, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6RmgCUXQFuHZ0Tj8rw1uMEyTRgE', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--0520e3e2-5535-40e2-a12f-85844714da9b-0', usage_metadata={'input_tokens': 284, 'output_tokens': 37, 'total_tokens': 321, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='写入用户信息：user_id: iris_10001 content: age: 20', additional_kwargs={}, response_metadata={}, id='5c4230b9-5eda-4ea0-81ce-06621774f5e6'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 345, 'total_tokens': 383, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6SrhnzQ3GIBi9EULfPlxeDo8Los', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--aeaefc3d-5ae2-468f-a821-c95e1f8ab0b8-0', tool_calls=[{'name': 'write_file', 'args': {'file_path': 'user_info_iris_10001.txt', 'content': 'user_id: iris_10001\nage: 20'}, 'id': 'call_t9mphBNPHLcajoBT1trBYP1w', 'type': 'tool_call'}], usage_metadata={'input_tokens': 345, 'output_tokens': 38, 'total_tokens': 383, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'write_file', 'args': {'file_path': 'user_info_iris_10001.txt', 'content': 'user_id: iris_10001\nage: 20'}, 'description': "Tool execution pending approval\n\nTool: write_file\nArgs: {'file_path': 'user_info_iris_10001.txt', 'content': 'user_id: iris_10001\\nage: 20'}"}], 'review_configs': [{'action_name': 'write_file', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='3af93c8918e40dcc52f64cd153c26895')]}

# %%
# # 通过中断
# agent.invoke(
#     Command( 
#         resume={"decisions": [{"type": "approve"}]}  # or "edit", "reject"
#     ), 
#     config=config # Same thread ID to resume the paused conversation
# )

# %%
from pprint import pprint
pprint(resp["__interrupt__"])
# Out:
# [Interrupt(value={'action_requests': [{'args': {'content': 'user_id: '
#                                                            'iris_10001\n'
#                                                            'age: 20',
#                                                 'file_path': 'user_info_iris_10001.txt'},
#                                        'description': 'Tool execution pending '
#                                                       'approval\n'
#                                                       '\n'
#                                                       'Tool: write_file\n'
#                                                       "Args: {'file_path': "
#                                                       "'user_info_iris_10001.txt', "
#                                                       "'content': 'user_id: "
#                                                       "iris_10001\\nage: 20'}",
#                                        'name': 'write_file'}],
#                   'review_configs': [{'action_name': 'write_file',
#                                       'allowed_decisions': ['approve',
#                                                             'edit',
#                                                             'reject']}]},
#            id='3af93c8918e40dcc52f64cd153c26895')]

# %%
# # 编辑中断
# agent.invoke(
#     Command(
#         resume={
#             "decisions": [
#                 {
#                     "type": "edit",
#                     "edited_action": {
#                         "name": "write_file",  # 填写 tool_name
#                         "args": {"file_path": "user_info_iris_10001.txt", "content": "user_id: iris_10001"},
#                     }
#                 }
#             ]
#         }
#     ),
#     config=config  # Same thread ID to resume the paused conversation
# )
# Out:
# {'messages': [HumanMessage(content='写入用户信息：user_id: iris_10001 content: age: 20', additional_kwargs={}, response_metadata={}, id='11b05285-65ac-4f73-a221-c68198873176'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 84, 'total_tokens': 122, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6NXLrULV2Y9zOw1zWNxvdWNEXd1', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6b9a9873-b1ae-4cce-bc8b-9462b2265bc1-0', tool_calls=[{'name': 'write_file', 'args': {'file_path': 'user_info_iris_10001.txt', 'content': 'user_id: iris_10001\nage: 20'}, 'id': 'call_c0FYL4BzdDPYpCVDOBWh1ZuJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 84, 'output_tokens': 38, 'total_tokens': 122, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='文件 user_info_iris_10001.txt 已写入, 内容为 user_id: iris_10001\nage: 20', name='write_file', id='5cf5166b-19e5-4731-8b7f-16155038c2f1', tool_call_id='call_c0FYL4BzdDPYpCVDOBWh1ZuJ'),
#   AIMessage(content='用户信息已成功写入，文件名为 `user_info_iris_10001.txt`，内容如下：\n\n```\nuser_id: iris_10001\nage: 20\n```', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 156, 'total_tokens': 198, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6NYEd2wKgLcG2Ij4jXB0GENKCT6', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--243a5def-cecc-4f25-8e54-025a1e8f0549-0', usage_metadata={'input_tokens': 156, 'output_tokens': 42, 'total_tokens': 198, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='写入用户信息：user_id: iris_10001 content: age: 20', additional_kwargs={}, response_metadata={}, id='29a94b59-b973-4c3e-9a4f-41264997e6fd'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 222, 'total_tokens': 260, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6Pvu6FgpPRlRn9DFiMeAn1NXzx5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--eb8a578f-c3fe-40af-9b97-012794a66617-0', tool_calls=[{'type': 'tool_call', 'name': 'write_file', 'args': {'file_path': 'user_info_iris_10001.txt', 'content': 'user_id: iris_10001'}, 'id': 'call_BHbEklckoRNTfwnV56wdQdrk'}], usage_metadata={'input_tokens': 222, 'output_tokens': 38, 'total_tokens': 260, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='文件 user_info_iris_10001.txt 已写入, 内容为 user_id: iris_10001', name='write_file', id='af286ee0-743f-42c7-af3e-c218e93c25dc', tool_call_id='call_BHbEklckoRNTfwnV56wdQdrk'),
#   AIMessage(content='用户信息已成功写入，文件名为 `user_info_iris_10001.txt`，内容如下：\n\n```\nuser_id: iris_10001\n```', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 284, 'total_tokens': 321, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6RmgCUXQFuHZ0Tj8rw1uMEyTRgE', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--0520e3e2-5535-40e2-a12f-85844714da9b-0', usage_metadata={'input_tokens': 284, 'output_tokens': 37, 'total_tokens': 321, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
# 拒绝中断

agent.invoke(
    Command(
        resume={
            "decisions": [
                {
                    "type": "reject",
                    "message": "添加的信息不合规，拒绝实施。",
                }
            ]
        }
    ),
    config=config  
)
# Out:
# {'messages': [HumanMessage(content='写入用户信息：user_id: iris_10001 content: age: 20', additional_kwargs={}, response_metadata={}, id='11b05285-65ac-4f73-a221-c68198873176'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 84, 'total_tokens': 122, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6NXLrULV2Y9zOw1zWNxvdWNEXd1', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6b9a9873-b1ae-4cce-bc8b-9462b2265bc1-0', tool_calls=[{'name': 'write_file', 'args': {'file_path': 'user_info_iris_10001.txt', 'content': 'user_id: iris_10001\nage: 20'}, 'id': 'call_c0FYL4BzdDPYpCVDOBWh1ZuJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 84, 'output_tokens': 38, 'total_tokens': 122, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='文件 user_info_iris_10001.txt 已写入, 内容为 user_id: iris_10001\nage: 20', name='write_file', id='5cf5166b-19e5-4731-8b7f-16155038c2f1', tool_call_id='call_c0FYL4BzdDPYpCVDOBWh1ZuJ'),
#   AIMessage(content='用户信息已成功写入，文件名为 `user_info_iris_10001.txt`，内容如下：\n\n```\nuser_id: iris_10001\nage: 20\n```', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 156, 'total_tokens': 198, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6NYEd2wKgLcG2Ij4jXB0GENKCT6', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--243a5def-cecc-4f25-8e54-025a1e8f0549-0', usage_metadata={'input_tokens': 156, 'output_tokens': 42, 'total_tokens': 198, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='写入用户信息：user_id: iris_10001 content: age: 20', additional_kwargs={}, response_metadata={}, id='29a94b59-b973-4c3e-9a4f-41264997e6fd'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 222, 'total_tokens': 260, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6Pvu6FgpPRlRn9DFiMeAn1NXzx5', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--eb8a578f-c3fe-40af-9b97-012794a66617-0', tool_calls=[{'name': 'write_file', 'args': {'file_path': 'user_info_iris_10001.txt', 'content': 'user_id: iris_10001'}, 'id': 'call_BHbEklckoRNTfwnV56wdQdrk', 'type': 'tool_call'}], usage_metadata={'input_tokens': 222, 'output_tokens': 38, 'total_tokens': 260, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='文件 user_info_iris_10001.txt 已写入, 内容为 user_id: iris_10001', name='write_file', id='af286ee0-743f-42c7-af3e-c218e93c25dc', tool_call_id='call_BHbEklckoRNTfwnV56wdQdrk'),
#   AIMessage(content='用户信息已成功写入，文件名为 `user_info_iris_10001.txt`，内容如下：\n\n```\nuser_id: iris_10001\n```', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 284, 'total_tokens': 321, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6RmgCUXQFuHZ0Tj8rw1uMEyTRgE', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--0520e3e2-5535-40e2-a12f-85844714da9b-0', usage_metadata={'input_tokens': 284, 'output_tokens': 37, 'total_tokens': 321, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='写入用户信息：user_id: iris_10001 content: age: 20', additional_kwargs={}, response_metadata={}, id='5c4230b9-5eda-4ea0-81ce-06621774f5e6'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 345, 'total_tokens': 383, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6SrhnzQ3GIBi9EULfPlxeDo8Los', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--aeaefc3d-5ae2-468f-a821-c95e1f8ab0b8-0', tool_calls=[{'name': 'write_file', 'args': {'file_path': 'user_info_iris_10001.txt', 'content': 'user_id: iris_10001\nage: 20'}, 'id': 'call_t9mphBNPHLcajoBT1trBYP1w', 'type': 'tool_call'}], usage_metadata={'input_tokens': 345, 'output_tokens': 38, 'total_tokens': 383, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='添加的信息不合规，拒绝实施。', name='write_file', id='d72239ca-515d-47ee-a3d6-73b1aab83b38', tool_call_id='call_t9mphBNPHLcajoBT1trBYP1w', status='error'),
#   AIMessage(content='由于某些不合规的原因，无法写入用户信息。请确认内容格式或者提供新的信息。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 400, 'total_tokens': 426, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-Ch6SwdYQk2ELkVRsZ0LmC5QL07dAE', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--8e768efe-cec8-4966-95dc-fe0bc4d586b8-0', usage_metadata={'input_tokens': 400, 'output_tokens': 26, 'total_tokens': 426, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
