# %%
# 配置开发环境
import os
from dotenv import load_dotenv
from pathlib import Path
from loguru import logger


load_dotenv()
root_path = Path.cwd().parent.parent

str(root_path), os.getenv("OPENAI_BASE_URL"), os.getenv("OPENAI_API_KEY")

# %% [markdown]
# # 模型

# %% [markdown]
# # 创建模型

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model = "openai:gpt-4o-mini",
    temperature=0.8,
    max_tokens=512,
    timeout=30
)

# %% [markdown]
# # 调用模型

# %% [markdown]
# ## invoke()

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-4o-mini")
resp = model.invoke("Hello, how are you?")

print(resp)
# Out:
# content="Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?" additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 13, 'total_tokens': 44, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-ChnxLceT0vqc9gAChh3VSbXeKfsOe', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--ce00144f-1f0a-4128-95ca-55912c97c929-0' usage_metadata={'input_tokens': 13, 'output_tokens': 31, 'total_tokens': 44, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# ## stream()

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-4o-mini")

for chunk in model.stream("什么是 LangChain 框架？"):
    print(chunk.text, end="", flush=True)
# Out:
# LangChain 是一个用于构建与自然语言处理（NLP）和大型语言模型（LLM）交互的应用程序的框架。它提供了一系列工具和组件，帮助开发者快速构建、训练和集成语言模型到他们的应用程序中。LangChain 的关键功能包括：
#
# 1. **模块化设计**：LangChain 采用模块化设计，使开发者能根据需求组合不同的组件，例如文本处理、对话管理、数据存储等。
#
# 2. **多种语言模型的支持**：LangChain 支持多种大型语言模型，包括 OpenAI 的 GPT 系列、Hugging Face 的 Transformers 模型等，方便开发者选择适合他们需求的模型。
#
# 3. **上下文管理**：它提供了上下文管理工具，使开发者能够更好地处理和维护对话状态，提升用户体验。
#
# 4. **数据连接**：LangChain 能够与多种数据源集成，允许开发者从外部数据库或API中提取和处理信息。
#
# 5. **易用性**：LangChain 提供用户友好的接口，使得非技术用户也能轻松上手。
#
# 通过这些功能，LangChain 使得构建聊天机器人、对话系统、问答应用等变得更加高效和灵活。

# %% [markdown]
# ## batch()

# %%
model = init_chat_model("gpt-4o-mini")

responses = model.batch([
    "什么是 Python ？",
    "什么是 LangChain 框架？",
    "怎样理解 ai agent 概念？"
])

for response in responses:
    print(response)
# Out:
# content='Python 是一种高级编程语言，由 Guido van Rossum 于 1991 年首次发布。它以简洁、易读的语法而著称，适合初学者和专业开发者使用。Python 支持多种编程范式，包括面向对象编程、结构化编程和函数式编程。\n\nPython 的主要特点包括：\n\n1. **易读性**：Python 的语法设计注重可读性，代码简洁，便于理解。\n2. **多平台**：Python 可以在多种操作系统上运行，如 Windows、macOS 和 Linux。\n3. **丰富的库**：Python 拥有大量的标准库和第三方库，涵盖了科学计算、数据分析、人工智能、网络开发等多个领域。\n4. **动态类型**：Python 是动态类型语言，变量不需要提前声明类型。\n5. **广泛用途**：Python 可以用于 web 开发、数据分析、机器学习、自动化脚本、网络爬虫等多种应用。\n\n由于其强大的功能和灵活性，Python 已成为当今最流行的编程语言之一，被广泛应用于学术研究、工业界和技术公司。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 261, 'prompt_tokens': 12, 'total_tokens': 273, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-ChnziRSw0hQ4d45g3wnyyLdBJQIP3', 'finish_reason': 'stop', 'logpr
# ...

# %% [markdown]
# 默认情况下， batch() 仅返回整个批次的最终输出。如果我们想在生成过程中接收每个单独输入的输出结果，可以使用 batch_as_completed() 来流式处理结果：

# %%
for response in model.batch_as_completed([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
]):
    print(response)
# Out:
# (0, AIMessage(content='Parrots have colorful feathers for several evolutionary and ecological reasons:\n\n1. **Camouflage**: In their natural habitats, which often include lush tropical forests, vibrant feather colors can help parrots blend into their surroundings. The bright greens, yellows, and reds can mimic the colors of fruits, flowers, and leaves, providing some level of camouflage from predators.\n\n2. **Mating Displays**: Bright and varied plumage can be an important factor in attracting mates. Colorful feathers often signal health and genetic fitness, making them appealing to potential partners. Many species of parrots engage in visual displays that showcase their plumage during courtship.\n\n3. **Social Signaling**: Colorful feathers can also serve as a form of communication among parrots. Variations in color and patterns can convey different information about the individual, such as age, health status, or social hierarchy within a group.\n\n4. **Species Differentiation**: 
# ...
